# %%
import time
start = time.time()

a = [i for i in range(100000000)]

print(time.time() - start)
# Out:
# 12.982117891311646

# %%
import numpy as np
import time
start = time.time()

a = np.arange(100000000)

print(time.time() - start)
# Out:
# 9.969877004623413

# %%
# one dimensional and multiplication
import numpy as np
a = np.array([1,2,3])
b = np.array([4,5,6])
print(a*b)
print(a)
# Out:
# [ 4 10 18]
# [1 2 3]

# %%
# 2 dimensional array
import numpy as np
b = np.array([[9.0, 8.1, 5.3], [1.1,2.4,5.6]])
print(b)
# Out:
# [[9.  8.1 5.3]
#  [1.1 2.4 5.6]]

# %%
#get dimensions
b.ndim
# Out:
# 2

# %%
# get shape
a.shape
b.shape
# Out:
# (2, 3)

# %%
# get type
a.dtype
b.dtype
# Out:
# dtype('float64')

# %%
# get size
a.itemsize
b.itemsize
# Out:
# 8

# %%
# total size
a.size
b.size
# Out:
# 6
