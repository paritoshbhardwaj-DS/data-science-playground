# %% [markdown]
# Input in same line

# %%
m , n = map(int, input().strip().split())
print(m,n)
# strip() is used to remove leading and trailing whitespace
# Out:
# 2 3

# %% [markdown]
# Input in different line

# %%
m = int(input())
n = int(input())
print(m)
print(n)
# Out:
# 2
# 3
