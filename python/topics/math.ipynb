# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
#Euler's number
math.e
# Out:
# 2.718281828459045

# %%
#square root
math.sqrt(5)
# Out:
# 4.0

# %%
#raised to the power
math.pow(2,2)
# Out:
# 4.0

# %%
#factorial
math.factorial(3)
# Out:
# 6

# %%
#ceiling - smallest integer >= x
math.ceil(4.2)
# Out:
# 5

# %%
#floor - smallest integer >= x
math.floor(4.2)
# Out:
# 4

# %%
#absolute value
math.fabs(3/2)
# Out:
# 1.5

# %% [markdown]
# Trignometric functions
#
#
# math.degrees(x) #-> radian to degree
#
#
# math.radians(30) #-> degrees to radian
#
# math.sin(x)
#
# math.cos(x)
#
# math.tan(x)

# %%
print(math.sin(math.radians(30)))
# Out:
# 0.49999999999999994

# %% [markdown]
# Logarithmic functions
#
# math.log(x) → natural log
#
# math.log10(x) → base‑10 log

# %%
print(math.log(10))
print(math.log10(100))
# Out:
# 2.302585092994046
# 2.0

# %% [markdown]
# Works only with numbers, not lists
#
# Does not support complex numbers → use cmath for that
