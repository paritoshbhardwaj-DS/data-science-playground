# %% [markdown]
# https://www.hackerrank.com/challenges/python-sort-sort/problem?isFullScreen=true

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

if __name__ == '__main__':
    nm = input().split()

    n = int(nm[0])

    m = int(nm[1])

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    # till now array has been created
    # arr =  [[10, 2, 5], [7, 1, 0], [9, 9, 9], [1, 23, 12], [6, 5, 9]]
    # #
    k = int(input())

    for i in arr:
        result = sorted(arr, key=lambda x: x[k])

    for a in result:
        for b in a:
            print(b, end=" ")
        print()
# Out:
# 7 1 0
# 10 2 5
# 6 5 9
# 9 9 9
# 1 23 12
