# %% [markdown]
# https://www.hackerrank.com/challenges/xml-1-find-the-score/problem?isFullScreen=true

# %%
import sys
import xml.etree.ElementTree as etree

def get_attr_number(node):
    return len(node.items()) + sum([get_attr_number(x) for x in node])

if __name__ == '__main__':
    sys.stdin.readline()
    xml = sys.stdin.read()
    tree = etree.ElementTree(etree.fromstring(xml))
    root = tree.getroot()
    print(get_attr_number(root))
# Out:
# Traceback (most recent call last):
#
#   File ~\pcint\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[36], line 10
#     tree = etree.ElementTree(etree.fromstring(xml))
#
#   File ~\AppData\Local\Programs\Python\Python314\Lib\xml\etree\ElementTree.py:1353 in XML
#     return parser.close()
#
#   File <string>
#
# ParseError: no element found: line 1, column 0

# %%
import sys
import xml.etree.ElementTree as ET
import html

xml_data = """
<feed xml:lang='en'>
    <title>HackerRank</title>
    <subtitle lang='en'>Programming challenges</subtitle>
    <link rel='alternate' type='text/html' href='http://hackerrank.com/'/>
    <updated>2013-12-25T12:00:00</updated>
</feed>
"""
xml_data = html.unescape(xml_data)
root = ET.fromstring(xml_data)
a = []
for items in root.iter():
    print(items)
# Out:
# <Element 'feed' at 0x000001AADC7BE250>
# <Element 'title' at 0x000001AADC7BE430>
# <Element 'subtitle' at 0x000001AADC7BE480>
# <Element 'link' at 0x000001AADC7BE4D0>
# <Element 'updated' at 0x000001AADC7BE520>
