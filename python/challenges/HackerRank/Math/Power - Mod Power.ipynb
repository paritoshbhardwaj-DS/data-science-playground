# %% [markdown]
# https://www.hackerrank.com/challenges/python-power-mod-power/problem?isFullScreen=true

# %%
pow(2,3)
# Out:
# 8

# %%
a = int(input())
b = int(input())
m = int(input())
print(pow(a,b))
print(pow(a,b)%m)
# Out:
# 81
# 1
