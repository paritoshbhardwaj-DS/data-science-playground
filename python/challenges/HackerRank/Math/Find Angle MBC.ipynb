# %% [markdown]
# https://www.hackerrank.com/challenges/find-angle/problem?isFullScreen=true
#
# c2 = a2 + b2 − 2abcos(θ) - if all 3 sides of triangle in known

# %%
import math
a = 3
b = 4
c = 5
theta_rad = math.acos((a*a + b*b - c*c)/ (2*a*b))
theta_deg = math.degrees(theta_rad)
print(theta_deg)
# Out:
# 90.0

# %%
import math
a = int(input())
b = int(input())
c = int(math.sqrt(a*a + b*b))


theta_rad1 = math.asin(a/c)
theta_deg1 = math.degrees(theta_rad1)

d = math.sqrt(b*b + ((c/2)*(c/2)) - 2*b*(c/2)* math.cos(theta_rad1))

theta_rad2 = math.acos((b*b + d*d - ((c/2)*(c/2)))/(2*b*d))
theta_deg2 = math.degrees(theta_rad2)
print((str(math.ceil(theta_deg2)))+ chr(176))
# not optimized and incorrect for one test case- coz solved in only one plane
# Out:
# 45°

# %%
# taking coordinates
A = (0,a)
B = (b,0)
C = (0,0)

M = (b/2, a/2)

# angle MBC is angle between BC and CM -> tan(θ) = (a/2) / (b/2)  = a/b

import math
a = int(input())
b = int(input())
print(str(round(math.degrees(math.atan(a/b))))+ chr(176))
# Out:
# 45°
