# %% [markdown]
# https://www.hackerrank.com/challenges/calendar-module/problem?isFullScreen=true

# %%
import calendar
m,d,y = map(int, input().split())
wd = calendar.weekday(y, m, d)
day = calendar.day_name[wd].upper()
print(day)

# print(calendar.month(2015, 5))
# Out:
# WEDNESDAY
