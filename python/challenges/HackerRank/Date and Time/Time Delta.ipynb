# %% [markdown]
# https://www.hackerrank.com/challenges/python-time-delta/problem?isFullScreen=true

# %%
from datetime import datetime

s1 = "Sun 10 May 2015 13:54:36 -0700"
s2 = "Sun 10 May 2015 13:54:36 -0000"
dt1 = datetime.strptime(s1, "%a %d %b %Y %H:%M:%S %z")
dt2 = datetime.strptime(s2, "%a %d %b %Y %H:%M:%S %z")
print(dt1)
print(dt1.tzinfo)
print(dt2)
print(dt2.tzinfo)
diff = dt1-dt2
print(diff.total_seconds())
# Out:
# 2015-05-10 13:54:36-07:00
# UTC-07:00
# 2015-05-10 13:54:36+00:00
# UTC
# 25200.0

# %%
#!/bin/python3

import math
import os
import random
import re
import sys
from datetime import datetime

# Complete the time_delta function below.
def time_delta(t1, t2):
    format = "%a %d %b %Y %H:%M:%S %z"
    date1 = datetime.strptime(t1, format)
    date2 = datetime.strptime(t2, format)
    return str(int(abs((date2-date1).total_seconds())))

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input().strip())

    for t_itr in range(t):
        t1 = input().strip()

        t2 = input().strip()

        delta = time_delta(t1, t2)

        fptr.write(delta + '\n')

    fptr.close()
# Out:
# 2015-05-02 19:54:36+05:30
# UTC+05:30
# 2015-05-01 13:54:36+00:00
# UTC
# 88200
