# %% [markdown]
# https://www.hackerrank.com/challenges/no-idea/problem?isFullScreen=true

# %% [markdown]
# There is an array of n integers. There are also 2 disjoint sets,  and , each containing  integers. You like all the integers in set  and dislike all the integers in set . Your initial happiness is . For each  integer in the array, if , you add  to your happiness. If , you add  to your happiness. Otherwise, your happiness does not change. Output your final happiness at the end.

# %% [markdown]
# array of n integers
# A B disjoint sets / each containing M integers
# A like
# B dislike
# initial happiness = 0
# for each i in array if i belongs to A +1 happiness if to B -1

# %%
# m , n = map(int, input().strip().split())
# N = map(int, input().strip().split()))
# A = set(map(int, input().strip().split()))
# B = set(map(int, input().strip().split()))
N = [1,2,3,5,6,1]
A = {1,2}
B = {2,3}
score = 0
for items in N:

    if items in A:
        score += 1

for items in N:
    if items in B:
        score -= 1
print(score)
# Out:
# 1

# %% [markdown]
# Above code is not giving right answer when the array has duplicate entries.
# Bec i declared that as set and set does not include duplicate values

# %%
K = [1,2,3,4,5,6,1]
A1 = {1,2}
B1 = {2,3}
score = 0
for items in K:
    # print("items:", items)
    if items in A1:
        score += 1
    if items in B1:
        score -= 1
print(score)
# Out:
# 1

# %% [markdown]
# Now above code is right

# %%
m , n = map(int, input().strip().split())
N = list(map(int, input().strip().split()))
A = set(map(int, input().strip().split()))
B = set(map(int, input().strip().split()))
score = 0
for items in N:

    if items in A:
        score += 1

for items in N:
    if items in B:
        score -= 1
print(score)
# Out:
# 1
