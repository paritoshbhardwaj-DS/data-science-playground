# %% [markdown]
# https://www.hackerrank.com/challenges/py-set-add/problem?isFullScreen=true
#
# If we want to add a single element to an existing set, we can use the .add() operation.
# It adds the element to the set and returns 'None'.

# %%
s = set('HackerRank')
s.add('H')
print(s)
# Out:
# {'r', 'R', 'k', 'H', 'a', 'e', 'c', 'n'}

# %%
set(['a', 'c', 'e', 'H', 'k', 'n', 'r', 'R'])
print(s.add('HackerRank'))
# Out:
# None

# %%
print(s)
# Out:
# {'HackerRank', 'r', 'R', 'k', 'H', 'a', 'e', 'c', 'n'}

# %% [markdown]
# Task
# Apply your knowledge of the .add() operation to help your friend Rupal.
# Rupal has a huge collection of country stamps. She decided to count the total number of distinct country stamps in her collection. She asked for your help. You pick the stamps one by one from a stack of N country stamps.
# Find the total number of distinct country stamps.

# %% [markdown]
# Input:
# N - the total number of country stamps
#
# Then next N lines contains the name of the country where the stamp is from.
# Output the total number of distinct country stamps on a single line.

# %%
N = int(input()) # take input N
count = set() # define an empty set
for i in range(N): # iterate over N to take country input
    a = input() # take input in a
    count.add(a) # add the input in empty set
print(len(count)) # print length
# Out:
# 2
