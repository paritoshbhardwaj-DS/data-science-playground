# %% [markdown]
# https://www.hackerrank.com/challenges/py-check-subset/problem?isFullScreen=true
#
# You are given two sets,  and .
# Your job is to find whether set  is a subset of set .
#
# If set  is subset of set , print True.
# If set  is not a subset of set , print False.

# %%
# below solution is not optimum
A1 = set([1,2,3,5,6])
B1 = set([9,8,5,6,3,2,1,4,7])

A2 = set([2])
B2 = set([3,6,5,4,1])


A3 = set([1,2,3,5,6,8,9])
B3 = set([9,8,2])

sym1 = A1.intersection(B1)
if sym1 != A1:
    print(False)
else:
    print(True)

sym2 = A2.intersection(B2)
if sym2 != A2:
    print(False)
else:
    print(True)

sym3 = A3.intersection(B3)
if sym3 != A3:
    print(False)
else:
    print(True)
# Out:
# True
# False
# False

# %%
# checked the solution online
for i in range(int(input())):
    a = int(input())
    set_a = set(map(int, input().split()))

    b = int(input())
    set_b = set(map(int, input().split()))

    if len(set_a - set_b) == 0:
        print("True")
    else:
        print("False")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for i in range(int(input())):
#       2     a = int(input())
#       3     set_a = set(map(int, input().split()))
#
# ValueError: invalid literal for int() with base 10: '3\n5\n1 2 3 5 6\n9\n9 8 5 6 3 2 1 4 7\n1\n2\n5\n3 6 5 4 1\n7\n1 2 3 5 6 8 9\n3\n9 8 2'

# %%
# lets see how + and - works
# (-) -> shows the difference in the sets
A = set([2])
B = set([3,6,5,4,1])
print(A-B)
# 2 not in B
# Out:
# {2}

# %% [markdown]
# A+B is not valid coz + is not defined for sets
# correct way -

# %%
# union
A = set([2])
B = set([3,6,5,4,1])
print(A|B)
print(A.union(B))
print(A & B) # intersection of common elements
print(A ^ B)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}
# set()
# {1, 2, 3, 4, 5, 6}
