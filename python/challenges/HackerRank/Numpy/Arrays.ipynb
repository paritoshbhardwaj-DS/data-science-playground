# %% [markdown]
# https://www.hackerrank.com/challenges/np-arrays/problem?isFullScreen=true

# %%
#print array in reverse - 1 2 3 4 -8 -10
import numpy

def arrays(arr):
    numpy.array((arr))
    return (arr[:-1])

arr = input().strip().split(' ')
result = arrays(arr)
print(result)
# Out:
# ['1', '2', '3', '4', '-8']
